# %% [markdown]
# <a href="https://colab.research.google.com/github/spps-supalerk/ChatBot/blob/main/SET_Scrapy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Scrape Data
from bs4 import BeautifulSoup
import requests
import urllib.parse
import time
from datetime import datetime
import re

# Manipulate Data
import numpy as np
import pandas as pd

# Ignore Error
import warnings
warnings.filterwarnings('ignore')

# %%
base_url = 'https://www.set.or.th/set/commonslookup.do?language=th&country=TH&prefix={}'
prefix_list = ['NUMBER'] + list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')

# record timestamp
scraped_time = datetime.now()
scraped_time_text = scraped_time.strftime('%Y-%m-%d %H:%M:%S')

result = []
log = []

for prefix in prefix_list:
    url = base_url.format(prefix)
    
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    rows = soup.select('#maincontent table.table-profile tr')[1:]
    
    for row in rows:
        td_list = row.find_all('td')
        symbol = td_list[0].text.strip() if td_list else ''
        name = td_list[1].text.strip() if len(td_list) >= 2 else ''
        market = td_list[2].text.strip() if len(td_list) >= 3 else ''
        
        result.append((symbol, name, market, url, scraped_time_text))
        
    print(f'{prefix}: {len(rows)}')
    
    time.sleep(0.2)

print(f'Total: {len(result)} entries')

end_time = datetime.now()
mins, seconds = divmod((end_time-scraped_time).total_seconds(), 60)
print(f'Elapsed time: {int(mins)} minutes {int(seconds)} seconds')

df = pd.DataFrame(result, columns=['symbol','name','market','url','scraped_time'])

# export to json
output_file = 'stock_symbols.json'
df.to_json(output_file, orient='records', force_ascii=False, indent=2)
print(f'Result file: {output_file}')
# Out:
# NUMBER: 3
# A: 67
# B: 51
# C: 55
# D: 17
# E: 20
# F: 16
# G: 27
# H: 11
# I: 26
# J: 15
# K: 28
# L: 19
# M: 51
# N: 27
# O: 8
# P: 59
# Q: 7
# R: 18
# S: 119
# T: 109
# U: 20
# V: 11
# W: 17
# X: 1
# Y: 3
# Z: 3
# Total: 808 entries
# Elapsed time: 0 minutes 14 seconds
# Result file: stock_symbols.json

# %%
# read stock symbol list
symbol_filepath = './stock_symbols.json'
symbol_df = pd.read_json(symbol_filepath)

symbol_df = symbol_df[['symbol','name','market']]

# timestamp
scraped_time = datetime.now()
scraped_time_text = scraped_time.strftime('%Y-%m-%d %H:%M:%S')
scraped_time_part = scraped_time.strftime('%Y%m%d_%H%M%S')

print(f'WEB SCRAPING START: {scraped_time_text}\n')

base_url = 'https://www.set.or.th/set/factsheet.do?symbol={}&ssoPageId=3&language=th&country=TH'

result = []
log = []
n_total = symbol_df.shape[0]

for i,row in symbol_df.iterrows():
    symbol = row['symbol']
    
    try:
        url = base_url.format(urllib.parse.quote(symbol))
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        container = soup.select_one('body > table').find_all('tr',recursive=False)[2].td.find_all('table', recursive=False)[1]

        # header section
        header_section = container.find_all('tr', recursive=False)[0].td.table

        # industry/sector
        tokens = header_section.tr.td.table.find_all('td')[0].text.strip().split('/')
        industry = tokens[0].strip() if tokens else ''
        sector = tokens[1].strip() if len(tokens) > 1 else ''

        # value section
        value_section = container.find_all('tr', recursive=False)[1]
        labels = [re.sub(r'\s', ' ', td.text.strip()) for td in value_section.find_all('tr')[0].find_all('td')]
        values = [re.sub(r'\s', ' ', td.text.strip()) for td in value_section.find_all('tr')[1].find_all('td')]
        
        result_row = [('symbol', symbol), ('industry', industry), ('sector', sector)]
        result_row += list(zip(labels, values))
        result_row += [('url', url), ('scraped_time', scraped_time_text)]
                 
        result.append(dict(result_row))
        print(f'{i+1:5}/{n_total} {(i+1)/n_total:5.0%} [{symbol}] Done')
                 
    except Exception as e:
        error = e.__doc__
        print(f'{i+1:5}/{n_total} {(i+1)/n_total:5.0%} [{symbol}] error: {error}')
        
    log_msg = (symbol, error)
    log.append(log_msg)
    
    time.sleep(0.1)

end_time = datetime.now()
mins, seconds = divmod((end_time-scraped_time).total_seconds(), 60)
print(f'Elapsed time: {int(mins)} minutes {int(seconds)} seconds')

result_df = pd.DataFrame(result)
df = symbol_df.merge(result_df)

# export to json
output_file = f'./SET_factsheet_{scraped_time_part}.json'
df.to_json(output_file, orient='records', force_ascii=False, indent=2)
print(f'Result file: {output_file}')
# Out:
# WEB SCRAPING START: 2020-12-15 07:57:07
#
#     1/808    0% [2S] Done
#     2/808    0% [3K-BAT] Done
#     3/808    0% [7UP] Done
#     4/808    0% [A] Done
#     5/808    1% [A5] Done
#     6/808    1% [AAV] Done
#     7/808    1% [ABICO] Done
#     8/808    1% [ABM] Done
#     9/808    1% [ABPIF] Done
#    10/808    1% [ACAP] Done
#    11/808    1% [ACC] Done
#    12/808    1% [ACE] Done
#    13/808    2% [ACG] Done
#    14/808    2% [ADB] Done
#    15/808    2% [ADVANC] Done
#    16/808    2% [AEC] Done
#    17/808    2% [AEONTS] Done
#    18/808    2% [AF] Done
#    19/808    2% [AFC] Done
#    20/808    2% [AGE] Done
#    21/808    3% [AH] Done
#    22/808    3% [AHC] Done
#    23/808    3% [AI] Done
#    24/808    3% [AIE] Done
#    25/808    3% [AIMCG] Done
#    26/808    3% [AIMIRT] Done
#    27/808    3% [AIRA] Done
#    28/808    3% [AIT] Done
#    29/808    4% [AJ] Done
#    30/808    4% [AJA] Done
#    31/808    4% [AKP] Done
#    32/808    4% [AKR] Done
#    33/808    4% [ALL] Done
#    34/808    4% [ALLA] Done
#    35/808    4% [ALT] Done
#    36/808    4% [ALUCON] Done
#    37/808    5% [AMA] Done
#    38/808    5% [AMANAH] Done
#    39/808    5% [AMARIN] Done
#    40/808    5% [AMATA] Done
#    41/808    5% [AMATAR] Done
#    42/808    5% [AMATAV] Done
#    43/808    5% [AMC] Done
#    44/808    5% [ANAN] Done
#    45/808    6% [AOT] Done
#    46/808    6% [AP] Done
#    47/808    6% [APCO] Done
#    48/808    6% [APCS] Done
#    49/808    6% [APEX] Done
#    50/808    6% [APP] Done
#    51/808    6% [APURE] Done
#    52/808    6% [AQ] Done
#    53/808    7% [AQUA] Done
#    54/808    7% [ARIN] Done
#    55/808    7% [ARIP] Done
#    56/808    7% [ARROW] Done
#    57/808    7% [AS] Done
#    58/808    7% [ASAP] Done
#    59/808    7% [ASEFA] Done
#    60/808    7% [ASIA] Done
#    61/808    8% [ASIAN] Done
#    62/808    8% [ASIMAR] Done
#    63/808    8% [ASK] Done
#    64/808    8% [ASN] Done
#    65/808    8% [ASP] Done
#    66/808    8% [ATP30] Done
#    67/808    8% [AU] Done
#    68/808    8% [AUCT] Done
#    69/808    9% [AWC] Done
#    70/808    9% [AYUD] Done
#    71/808    9% [B] Done
#    72/808    9% [B-WORK] Done
#    73/808    9% [B52] Done
#    74/808    9% [BA] Done
#    75/808    9% [BAFS] Done
#    76/808    9% [BAM] Done
#    77/808   10% [BANPU] Done
#    78/808   10% [BAY] Done
#    79/808   10% [BBL] Done
#    80/808   10% [BC] Done
#    81/808   10% [BCH] Done
#    82/808   10% [BCP] Done
#    83/808   10% [BCPG] Done
#    84/808   10% [BCT] Done
#    85/808   11% [BDMS] Done
#    86/808   11% [BEAUTY] Done
#    87/808   11% [BEC] Done
#    88/808   11% [BEM] Done
#    89/808   11% [BFIT] Done
#    90/808   11% [BGC] Done
#    91/808   11% [BGRIM] Done
#    92/808   11% [BGT] Done
#    93/808   12% [BH] Done
#    94/808   12% [BIG] Done
#    95/808   12% [BIZ] Done
#    96/808   12% [BJC] Done
#    97/808   12% [BJCHI] Done
#    98/808   12% [BKD] Done
#    99/808   12% [BKER] Done
#   100/808   12% [BKI] Done
#   101/808   12% [BKKCP] Done
#   102/808   13% [BLA] Done
#   103/808   13% [BLAND] Done
#   104/808   13% [BLISS] Done
#   105/808   13% [BM] Done
#   106/808   13% [BOFFICE] Done
#   107/808   13% [BOL] Done
#   108/808   13% [BPP] Done
#   109/808   13% [BR] Done
#   110/808   14% [BROCK] Done
#   111/808   14% [BROOK] Done
#   112/808   14% [BRR] Done
#   113/808   14% [BRRGIF] Done
#   114/808   14% [BSBM] Done
#   115/808   14% [BSM] Done
#   116/808   14% [BTNC] Done
#   117/808   14% [BTS] Done
#   118/808   15% [BTSGIF] Done
#   119/808   15% [BTW] Done
#   120/808   15% [BUI] Done
#   121/808   15% [BWG] Done
#   122/808   15% [CAZ] Done
#   123/808   15% [CBG] Done
#   124/808   15% [CCET] Done
#   125/808   15% [CCP] Done
#   126/808   16% [CEN] Done
#   127/808   16% [CENTEL] Done
#   128/808   16% [CFRESH] Done
#   129/808   16% [CGD] Done
#   130/808   16% [CGH] Done
#   131/808   16% [CHARAN] Done
#   132/808   16% [CHAYO] Done
#   133/808   16% [CHEWA] Done
#   134/808   17% [CHG] Done
#   135/808   17% [CHO] Done
#   136/808   17% [CHOTI] Done
#   137/808   17% [CHOW] Done
#   138/808   17% [CI] Done
#   139/808   17% [CIG] Done
#   140/808   17% [CIMBT] Done
#   141/808   17% [CITY] Done
#   142/808   18% [CK] Done
#   143/808   18% [CKP] Done
#   144/808   18% [CM] Done
#   145/808   18% [CMAN] Done
#   146/808   18% [CMC] Done
#   147/808   18% [CMO] Done
#   148/808   18% [CMR] Done
#   149/808   18% [CNT] Done
#   150/808   19% [COL] Done
#   151/808   19% [COLOR] Done
#   152/808   19% [COM7] Done
#   153/808   19% [COMAN] Done
#   154/808   19% [COTTO] Done
#   155/808   19% [CPALL] Done
#   156/808   19% [CPF] Done
#   157/808   19% [CPH] Done
#   158/808   20% [CPI] Done
#   159/808   20% [CPL] Done
#   160/808   20% [CPN] Done
#   161/808   20% [CPNCG] Done
#   162/808   20% [CPNREIT] Done
#   163/808   20% [CPR] Done
#   164/808   20% [CPT] Done
#   165/808   20% [CPTGF] Done
#   166/808   21% [CPW] Done
#   167/808   21% [CRANE] Done
#   168/808   21% [CRC] Done
#   169/808   21% [CRD] Done
#   170/808   21% [CSC] Done
#   171/808   21% [CSP] Done
#   172/808   21% [CSR] Done
#   173/808   21% [CSS] Done
#   174/808   22% [CTARAF] Done
#   175/808   22% [CTW] Done
#   176/808   22% [CWT] Done
#   177/808   22% [D] Done
#   178/808   22% [DCC] Done
#   179/808   22% [DCON] Done
#   180/808   22% [DDD] Done
#   181/808   22% [DELTA] Done
#   182/808   23% [DEMCO] Done
#   183/808   23% [DHOUSE] Done
#   184/808   23% [DIF] Done
#   185/808   23% [DIMET] Done
#   186/808   23% [DOD] Done
#   187/808   23% [DOHOME] Done
#   188/808   23% [DREIT] Done
#   189/808   23% [DRT] Done
#   190/808   24% [DTAC] Done
#   191/808   24% [DTC] Done
#   192/808   24% [DTCI] Done
#   193/808   24% [DV8] Done
#   194/808   24% [EA] Done
#   195/808   24% [EASON] Done
#   196/808   24% [EASTW] Done
#   197/808   24% [ECF] Done
#   198/808   25% [ECL] Done
#   199/808   25% [EE] Done
#   200/808   25% [EFORL] Done
#   201/808   25% [EGATIF] Done
#   202/808   25% [EGCO] Done
#   203/808   25% [EKH] Done
#   204/808   25% [EMC] Done
#   205/808   25% [EP] Done
#   206/808   25% [EPG] Done
#   207/808   26% [ERW] Done
#   208/808   26% [ERWPF] Done
#   209/808   26% [ESSO] Done
#   210/808   26% [ESTAR] Done
#   211/808   26% [ETC] Done
#   212/808   26% [ETE] Done
#   213/808   26% [EVER] Done
#   214/808   26% [F&D] Done
#   215/808   27% [FANCY] Done
#   216/808   27% [FE] Done
#   217/808   27% [FLOYD] Done
#   218/808   27% [FMT] Done
#   219/808   27% [FN] Done
#   220/808   27% [FNS] Done
#   221/808   27% [FORTH] Done
#   222/808   27% [FPI] Done
#   223/808   28% [FPT] Done
#   224/808   28% [FSMART] Done
#   225/808   28% [FSS] Done
#   226/808   28% [FTE] Done
#   227/808   28% [FTREIT] Done
#   228/808   28% [FUTUREPF] Done
#   229/808   28% [FVC] Done
#   230/808   28% [GAHREIT] Done
#   231/808   29% [GBX] Done
#   232/808   29% [GC] Done
#   233/808   29% [GCAP] Done
#   234/808   29% [GEL] Done
#   235/808   29% [GENCO] Done
#   236/808   29% [GFPT] Done
#   237/808   29% [GGC] Done
#   238/808   29% [GIFT] Done
#   239/808   30% [GJS] Done
#   240/808   30% [GL] Done
#   241/808   30% [GLAND] Done
#   242/808   30% [GLOBAL] Done
#   243/808   30% [GLOCON] Done
#   244/808   30% [GOLDPF] Done
#   245/808   30% [GPI] Done
#   246/808   30% [GPSC] Done
#   247/808   31% [GRAMMY] Done
#   248/808   31% [GRAND] Done
#   249/808   31% [GREEN] Done
#   250/808   31% [GSC] Done
#   251/808   31% [GSTEEL] Done
#   252/808   31% [GTB] Done
#   253/808   31% [GULF] Done
#   254/808   31% [GUNKUL] Done
#   255/808   32% [GVREIT] Done
#   256/808   32% [GYT] Done
#   257/808   32% [HANA] Done
#   258/808   32% [HARN] Done
#   259/808   32% [HFT] Done
#   260/808   32% [HMPRO] Done
#   261/808   32% [HPF] Done
#   262/808   32% [HPT] Done
#   263/808   33% [HREIT] Done
#   264/808   33% [HTC] Done
#   265/808   33% [HTECH] Done
#   266/808   33% [HUMAN] Done
#   267/808   33% [HYDRO] Done
#   268/808   33% [ICC] Done
#   269/808   33% [ICHI] Done
#   270/808   33% [ICN] Done
#   271/808   34% [IFEC] Done
#   272/808   34% [IFS] Done
#   273/808   34% [IHL] Done
#   274/808   34% [IIG] Done
#   275/808   34% [III] Done
#   276/808   34% [ILINK] Done
#   277/808   34% [ILM] Done
#   278/808   34% [IMH] Done
#   279/808   35% [IMPACT] Done
#   280/808   35% [INET] Done
#   281/808   35% [INGRS] Done
#   282/808   35% [INOX] Done
#   283/808   35% [INSET] Done
#   284/808   35% [INSURE] Done
#   285/808   35% [INTUCH] Done
#   286/808   35% [IP] Done
#   287/808   36% [IRC] Done
#   288/808   36% [IRCP] Done
#   289/808   36% [IRPC] Done
#   290/808   36% [IT] Done
#   291/808   36% [ITD] Done
#   292/808   36% [ITEL] Done
#   293/808   36% [IVL] Done
#   294/808   36% [J] Done
#   295/808   37% [JAS] Done
#   296/808   37% [JASIF] Done
#   297/808   37% [JCK] Done
#   298/808   37% [JCKH] Done
#   299/808   37% [JCT] Done
#   300/808   37% [JKN] Done
#   301/808   37% [JMART] Done
#   302/808   37% [JMT] Done
#   303/808   38% [JR] Done
#   304/808   38% [JSP] Done
#   305/808   38% [JTS] Done
#   306/808   38% [JUBILE] Done
#   307/808   38% [JUTHA] Done
#   308/808   38% [JWD] Done
#   309/808   38% [K] Done
#   310/808   38% [KAMART] Done
#   311/808   38% [KASET] Done
#   312/808   39% [KBANK] Done
#   313/808   39% [KBS] Done
#   314/808   39% [KBSPIF] Done
#   315/808   39% [KC] Done
#   316/808   39% [KCAR] Done
#   317/808   39% [KCE] Done
#   318/808   39% [KCM] Done
#   319/808   39% [KDH] Done
#   320/808   40% [KGI] Done
#   321/808   40% [KIAT] Done
#   322/808   40% [KK] Done
#   323/808   40% [KKC] Done
#   324/808   40% [KKP] Done
#   325/808   40% [KOOL] Done
#   326/808   40% [KPNPF] Done
#   327/808   40% [KSL] Done
#   328/808   41% [KTB] Done
#   329/808   41% [KTC] Done
#   330/808   41% [KTIS] Done
#   331/808   41% [KUMWEL] Done
#   332/808   41% [KUN] Done
#   333/808   41% [KWC] Done
#   334/808   41% [KWG] Done
#   335/808   41% [KWM] Done
#   336/808   42% [KYE] Done
#   337/808   42% [L&E] Done
#   338/808   42% [LALIN] Done
#   339/808   42% [LANNA] Done
#   340/808   42% [LDC] Done
#   341/808   42% [LEE] Done
#   342/808   42% [LEO] Done
#   343/808   42% [LH] Done
#   344/808   43% [LHFG] Done
#   345/808   43% [LHHOTEL] Done
#   346/808   43% [LHK] Done
#   347/808   43% [LHPF] Done
#   348/808   43% [LHSC] Done
#   349/808   43% [LIT] Done
#   350/808   43% [LOXLEY] Done
#   351/808   43% [LPH] Done
#   352/808   44% [LPN] Done
#   353/808   44% [LRH] Done
#   354/808   44% [LST] Done
#   355/808   44% [LUXF] Done
#   356/808   44% [M] Done
#   357/808   44% [M-CHAI] Done
#   358/808   44% [M-II] Done
#   359/808   44% [M-PAT] Done
#   360/808   45% [M-STOR] Done
#   361/808   45% [MACO] Done
#   362/808   45% [MAJOR] Done
#   363/808   45% [MAKRO] Done
#   364/808   45% [MALEE] Done
#   365/808   45% [MANRIN] Done
#   366/808   45% [MATCH] Done
#   367/808   45% [MATI] Done
#   368/808   46% [MAX] Done
#   369/808   46% [MBAX] Done
#   370/808   46% [MBK] Done
#   371/808   46% [MBKET] Done
#   372/808   46% [MC] Done
#   373/808   46% [MCOT] Done
#   374/808   46% [MCS] Done
#   375/808   46% [MDX] Done
#   376/808   47% [MEGA] Done
#   377/808   47% [META] Done
#   378/808   47% [METCO] Done
#   379/808   47% [MFC] Done
#   380/808   47% [MFEC] Done
#   381/808   47% [MGT] Done
#   382/808   47% [MICRO] Done
#   383/808   47% [MIDA] Done
#   384/808   48% [MILL] Done
#   385/808   48% [MINT] Done
#   386/808   48% [MIPF] Done
#   387/808   48% [MIT] Done
#   388/808   48% [MITSIB] Done
#   389/808   48% [MJD] Done
#   390/808   48% [MJLF] Done
#   391/808   48% [MK] Done
#   392/808   49% [ML] Done
#   393/808   49% [MM] Done
#   394/808   49% [MNIT] Done
#   395/808   49% [MNIT2] Done
#   396/808   49% [MNRF] Done
#   397/808   49% [MODERN] Done
#   398/808   49% [MONO] Done
#   399/808   49% [MOONG] Done
#   400/808   50% [MORE] Done
#   401/808   50% [MPG] Done
#   402/808   50% [MPIC] Done
#   403/808   50% [MSC] Done
#   404/808   50% [MTC] Done
#   405/808   50% [MTI] Done
#   406/808   50% [MVP] Done
#   407/808   50% [NBC] Done
#   408/808   50% [NC] Done
#   409/808   51% [NCAP] Done
#   410/808   51% [NCH] Done
#   411/808   51% [NCL] Done
#   412/808   51% [NDR] Done
#   413/808   51% [NEP] Done
#   414/808   51% [NER] Done
#   415/808   51% [NETBAY] Done
#   416/808   51% [NEW] Done
#   417/808   52% [NEWS] Done
#   418/808   52% [NEX] Done
#   419/808   52% [NFC] Done
#   420/808   52% [NINE] Done
#   421/808   52% [NKI] Done
#   422/808   52% [NMG] Done
#   423/808   52% [NNCL] Done
#   424/808   52% [NOBLE] Done
#   425/808   53% [NOK] Done
#   426/808   53% [NPK] Done
#   427/808   53% [NRF] Done
#   428/808   53% [NSI] Done
#   429/808   53% [NTV] Done
#   430/808   53% [NUSA] Done
#   431/808   53% [NVD] Done
#   432/808   53% [NWR] Done
#   433/808   54% [NYT] Done
#   434/808   54% [OCC] Done
#   435/808   54% [OCEAN] Done
#   436/808   54% [OGC] Done
#   437/808   54% [OHTL] Done
#   438/808   54% [OISHI] Done
#   439/808   54% [ORI] Done
#   440/808   54% [OSP] Done
#   441/808   55% [OTO] Done
#   442/808   55% [PACE] Done
#   443/808   55% [PAE] Done
#   444/808   55% [PAF] Done
#   445/808   55% [PAP] Done
#   446/808   55% [PATO] Done
#   447/808   55% [PB] Done
#   448/808   55% [PCSGH] Done
#   449/808   56% [PDG] Done
#   450/808   56% [PDI] Done
#   451/808   56% [PDJ] Done
#   452/808   56% [PE] Done
#   453/808   56% [PERM] Done
#   454/808   56% [PF] Done
#   455/808   56% [PG] Done
#   456/808   56% [PHOL] Done
#   457/808   57% [PICO] Done
#   458/808   57% [PIMO] Done
#   459/808   57% [PJW] Done
#   460/808   57% [PK] Done
#   461/808   57% [PL] Done
#   462/808   57% [PLANB] Done
#   463/808   57% [PLANET] Done
#   464/808   57% [PLAT] Done
#   465/808   58% [PLE] Done
#   466/808   58% [PM] Done
#   467/808   58% [PMTA] Done
#   468/808   58% [POLAR] Done
#   469/808   58% [POMPUI] Done
#   470/808   58% [POPF] Done
#   471/808   58% [PORT] Done
#   472/808   58% [POST] Done
#   473/808   59% [PPF] Done
#   474/808   59% [PPM] Done
#   475/808   59% [PPP] Done
#   476/808   59% [PPPM] Done
#   477/808   59% [PPS] Done
#   478/808   59% [PR9] Done
#   479/808   59% [PRAKIT] Done
#   480/808   59% [PRAPAT] Done
#   481/808   60% [PREB] Done
#   482/808   60% [PRECHA] Done
#   483/808   60% [PRG] Done
#   484/808   60% [PRIME] Done
#   485/808   60% [PRIN] Done
#   486/808   60% [PRINC] Done
#   487/808   60% [PRM] Done
#   488/808   60% [PRO] Done
#   489/808   61% [PROSPECT] Done
#   490/808   61% [PROUD] Done
#   491/808   61% [PSH] Done
#   492/808   61% [PSL] Done
#   493/808   61% [PSTC] Done
#   494/808   61% [PT] Done
#   495/808   61% [PTG] Done
#   496/808   61% [PTL] Done
#   497/808   62% [PTT] Done
#   498/808   62% [PTTEP] Done
#   499/808   62% [PTTGC] Done
#   500/808   62% [PYLON] Done
#   501/808   62% [Q-CON] Done
#   502/808   62% [QH] Done
#   503/808   62% [QHHR] Done
#   504/808   62% [QHOP] Done
#   505/808   62% [QHPF] Done
#   506/808   63% [QLT] Done
#   507/808   63% [QTC] Done
#   508/808   63% [RAM] Done
#   509/808   63% [RATCH] Done
#   510/808   63% [RBF] Done
#   511/808   63% [RCI] Done
#   512/808   63% [RCL] Done
#   513/808   63% [RICHY] Done
#   514/808   64% [RJH] Done
#   515/808   64% [RML] Done
#   516/808   64% [ROCK] Done
#   517/808   64% [ROH] Done
#   518/808   64% [ROJNA] Done
#   519/808   64% [RP] Done
#   520/808   64% [RPC] Done
#   521/808   64% [RPH] Done
#   522/808   65% [RS] Done
#   523/808   65% [RSP] Done
#   524/808   65% [RT] Done
#   525/808   65% [RWI] Done
#   526/808   65% [S] Done
#   527/808   65% [S & J] Done
#   528/808   65% [S11] Done
#   529/808   65% [SAAM] Done
#   530/808   66% [SABINA] Done
#   531/808   66% [SABUY] Done
#   532/808   66% [SAFARI] Done
#   533/808   66% [SAK] Done
#   534/808   66% [SALEE] Done
#   535/808   66% [SAM] Done
#   536/808   66% [SAMART] Done
#   537/808   66% [SAMCO] Done
#   538/808   67% [SAMTEL] Done
#   539/808   67% [SANKO] Done
#   540/808   67% [SAPPE] Done
#   541/808   67% [SAT] Done
#   542/808   67% [SAUCE] Done
#   543/808   67% [SAWAD] Done
#   544/808   67% [SAWANG] Done
#   545/808   67% [SBPF] Done
#   546/808   68% [SC] Done
#   547/808   68% [SCB] Done
#   548/808   68% [SCC] Done
#   549/808   68% [SCCC] Done
#   550/808   68% [SCG] Done
#   551/808   68% [SCGP] Done
#   552/808   68% [SCI] Done
#   553/808   68% [SCM] Done
#   554/808   69% [SCN] Done
#   555/808   69% [SCP] Done
#   556/808   69% [SDC] Done
#   557/808   69% [SE] Done
#   558/808   69% [SE-ED] Done
#   559/808   69% [SEAFCO] Done
#   560/808   69% [SEAOIL] Done
#   561/808   69% [SEG] Done
#   562/808   70% [SELIC] Done
#   563/808   70% [SENA] Done
#   564/808   70% [SF] Done
#   565/808   70% [SFLEX] Done
#   566/808   70% [SFP] Done
#   567/808   70% [SFT] Done
#   568/808   70% [SGF] Done
#   569/808   70% [SGP] Done
#   570/808   71% [SHANG] Done
#   571/808   71% [SHR] Done
#   572/808   71% [SHREIT] Done
#   573/808   71% [SIAM] Done
#   574/808   71% [SICT] Done
#   575/808   71% [SIMAT] Done
#   576/808   71% [SINGER] Done
#   577/808   71% [SIRI] Done
#   578/808   72% [SIRIP] Done
#   579/808   72% [SIS] Done
#   580/808   72% [SISB] Done
#   581/808   72% [SITHAI] Done
#   582/808   72% [SK] Done
#   583/808   72% [SKE] Done
#   584/808   72% [SKN] Done
#   585/808   72% [SKR] Done
#   586/808   73% [SKY] Done
#   587/808   73% [SLM] Done
#   588/808   73% [SLP] Done
#   589/808   73% [SMART] Done
#   590/808   73% [SMIT] Done
#   591/808   73% [SMK] Done
#   592/808   73% [SMPC] Done
#   593/808   73% [SMT] Done
#   594/808   74% [SNC] Done
#   595/808   74% [SNP] Done
#   596/808   74% [SO] Done
#   597/808   74% [SOLAR] Done
#   598/808   74% [SONIC] Done
#   599/808   74% [SORKON] Done
#   600/808   74% [SPA] Done
#   601/808   74% [SPACK] Done
#   602/808   75% [SPALI] Done
#   603/808   75% [SPC] Done
#   604/808   75% [SPCG] Done
#   605/808   75% [SPF] Done
#   606/808   75% [SPG] Done
#   607/808   75% [SPI] Done
#   608/808   75% [SPRC] Done
#   609/808   75% [SPRIME] Done
#   610/808   75% [SPVI] Done
#   611/808   76% [SQ] Done
#   612/808   76% [SR] Done
#   613/808   76% [SRICHA] Done
#   614/808   76% [SRIPANWA] Done
#   615/808   76% [SSC] Done
#   616/808   76% [SSF] Done
#   617/808   76% [SSP] Done
#   618/808   76% [SSPF] Done
#   619/808   77% [SSSC] Done
#   620/808   77% [SST] Done
#   621/808   77% [SSTRT] Done
#   622/808   77% [STA] Done
#   623/808   77% [STANLY] Done
#   624/808   77% [STAR] Done
#   625/808   77% [STARK] Done
#   626/808   77% [STC] Done
#   627/808   78% [STEC] Done
#   628/808   78% [STGT] Done
#   629/808   78% [STHAI] Done
#   630/808   78% [STI] Done
#   631/808   78% [STPI] Done
#   632/808   78% [SUC] Done
#   633/808   78% [SUN] Done
#   634/808   78% [SUPER] Done
#   635/808   79% [SUPEREIF] Done
#   636/808   79% [SUSCO] Done
#   637/808   79% [SUTHA] Done
#   638/808   79% [SVH] Done
#   639/808   79% [SVI] Done
#   640/808   79% [SVOA] Done
#   641/808   79% [SWC] Done
#   642/808   79% [SYMC] Done
#   643/808   80% [SYNEX] Done
#   644/808   80% [SYNTEC] Done
#   645/808   80% [T] Done
#   646/808   80% [TACC] Done
#   647/808   80% [TAE] Done
#   648/808   80% [TAKUNI] Done
#   649/808   80% [TAPAC] Done
#   650/808   80% [TASCO] Done
#   651/808   81% [TBSP] Done
#   652/808   81% [TC] Done
#   653/808   81% [TCAP] Done
#   654/808   81% [TCC] Done
#   655/808   81% [TCCC] Done
#   656/808   81% [TCJ] Done
#   657/808   81% [TCMC] Done
#   658/808   81% [TCOAT] Done
#   659/808   82% [TEAM] Done
#   660/808   82% [TEAMG] Done
#   661/808   82% [TFFIF] Done
#   662/808   82% [TFG] Done
#   663/808   82% [TFI] Done
#   664/808   82% [TFMAMA] Done
#   665/808   82% [TGPRO] Done
#   666/808   82% [TH] Done
#   667/808   83% [THAI] Done
#   668/808   83% [THANA] Done
#   669/808   83% [THANI] Done
#   670/808   83% [THCOM] Done
#   671/808   83% [THE] Done
#   672/808   83% [THG] Done
#   673/808   83% [THIP] Done
#   674/808   83% [THL] Done
#   675/808   84% [THMUI] Done
#   676/808   84% [THRE] Done
#   677/808   84% [THREL] Done
#   678/808   84% [TIF1] Done
#   679/808   84% [TIGER] Done
#   680/808   84% [TIP] Done
#   681/808   84% [TIPCO] Done
#   682/808   84% [TISCO] Done
#   683/808   85% [TITLE] Done
#   684/808   85% [TIW] Done
#   685/808   85% [TK] Done
#   686/808   85% [TKN] Done
#   687/808   85% [TKS] Done
#   688/808   85% [TKT] Done
#   689/808   85% [TLGF] Done
#   690/808   85% [TLHPF] Done
#   691/808   86% [TM] Done
#   692/808   86% [TMB] Done
#   693/808   86% [TMC] Done
#   694/808   86% [TMD] Done
#   695/808   86% [TMI] Done
#   696/808   86% [TMILL] Done
#   697/808   86% [TMT] Done
#   698/808   86% [TMW] Done
#   699/808   87% [TNDT] Done
#   700/808   87% [TNH] Done
#   701/808   87% [TNITY] Done
#   702/808   87% [TNL] Done
#   703/808   87% [TNP] Done
#   704/808   87% [TNPC] Done
#   705/808   87% [TNPF] Done
#   706/808   87% [TNR] Done
#   707/808   88% [TOA] Done
#   708/808   88% [TOG] Done
#   709/808   88% [TOP] Done
#   710/808   88% [TOPP] Done
#   711/808   88% [TPA] Done
#   712/808   88% [TPAC] Done
#   713/808   88% [TPBI] Done
#   714/808   88% [TPCH] Done
#   715/808   88% [TPCORP] Done
#   716/808   89% [TPIPL] Done
#   717/808   89% [TPIPP] Done
#   718/808   89% [TPLAS] Done
#   719/808   89% [TPOLY] Done
#   720/808   89% [TPP] Done
#   721/808   89% [TPRIME] Done
#   722/808   89% [TPS] Done
#   723/808   89% [TQM] Done
#   724/808   90% [TR] Done
#   725/808   90% [TRC] Done
#   726/808   90% [TRITN] Done
#   727/808   90% [TRT] Done
#   728/808   90% [TRU] Done
#   729/808   90% [TRUBB] Done
#   730/808   90% [TRUE] Done
#   731/808   90% [TSC] Done
#   732/808   91% [TSE] Done
#   733/808   91% [TSF] Done
#   734/808   91% [TSI] Done
#   735/808   91% [TSR] Done
#   736/808   91% [TSTE] Done
#   737/808   91% [TSTH] Done
#   738/808   91% [TTA] Done
#   739/808   91% [TTCL] Done
#   740/808   92% [TTI] Done
#   741/808   92% [TTLPF] Done
#   742/808   92% [TTT] Done
#   743/808   92% [TTW] Done
#   744/808   92% [TU] Done
#   745/808   92% [TU-PF] Done
#   746/808   92% [TVD] Done
#   747/808   92% [TVI] Done
#   748/808   93% [TVO] Done
#   749/808   93% [TVT] Done
#   750/808   93% [TWP] Done
#   751/808   93% [TWPC] Done
#   752/808   93% [TWZ] Done
#   753/808   93% [TYCN] Done
#   754/808   93% [U] Done
#   755/808   93% [UAC] Done
#   756/808   94% [UBIS] Done
#   757/808   94% [UEC] Done
#   758/808   94% [UKEM] Done
#   759/808   94% [UMI] Done
#   760/808   94% [UMS] Done
#   761/808   94% [UNIQ] Done
#   762/808   94% [UOBKH] Done
#   763/808   94% [UP] Done
#   764/808   95% [UPA] Done
#   765/808   95% [UPF] Done
#   766/808   95% [UPOIC] Done
#   767/808   95% [URBNPF] Done
#   768/808   95% [UREKA] Done
#   769/808   95% [UT] Done
#   770/808   95% [UTP] Done
#   771/808   95% [UV] Done
#   772/808   96% [UVAN] Done
#   773/808   96% [UWC] Done
#   774/808   96% [VARO] Done
#   775/808   96% [VCOM] Done
#   776/808   96% [VGI] Done
#   777/808   96% [VI] Done
#   778/808   96% [VIBHA] Done
#   779/808   96% [VIH] Done
#   780/808   97% [VL] Done
#   781/808   97% [VNG] Done
#   782/808   97% [VNT] Done
#   783/808   97% [VPO] Done
#   784/808   97% [VRANDA] Done
#   785/808   97% [W] Done
#   786/808   97% [WACOAL] Done
#   787/808   97% [WAVE] Done
#   788/808   98% [WGE] Done
#   789/808   98% [WHA] Done
#   790/808   98% [WHABT] Done
#   791/808   98% [WHART] Done
#   792/808   98% [WHAUP] Done
#   793/808   98% [WICE] Done
#   794/808   98% [WIIK] Done
#   795/808   98% [WIN] Done
#   796/808   99% [WINNER] Done
#   797/808   99% [WORK] Done
#   798/808   99% [WORLD] Done
#   799/808   99% [WP] Done
#   800/808   99% [WPH] Done
#   801/808   99% [WR] Done
#   802/808   99% [XO] Done
#   803/808   99% [YCI] Done
#   804/808  100% [YGG] Done
#   805/808  100% [YUASA] Done
#   806/808  100% [ZEN] Done
#   807/808  100% [ZIGA] Done
#   808/808  100% [ZMICO] Done
# Elapsed time: 5 minutes 20 seconds
# Result file: ./SET_factsheet_20201215_075707.json
